# %%
import pandas as pd

# %%
mydata = pd.read_csv("EE411-012303-000742-eeg.txt", delimiter=" ", header=None)

# %%
mydata
# Out:
#       0         1         2         3         4         5         6   \
# 0    NaN  0.335385  0.366990  0.385173  0.338571  0.275073 -0.990754
# 1    NaN  0.335387  0.366984  0.385182  0.338580  0.275024 -0.990753
# 2    NaN  0.335389  0.366979  0.385189  0.338592  0.274971 -0.990755
# 3    NaN  0.335397  0.366975  0.385193  0.338601  0.274918 -0.990753
# 4    NaN  0.335409  0.366972  0.385194  0.338605  0.274862 -0.990751
# ...   ..       ...       ...       ...       ...       ...       ...
# 4864 NaN  0.363707  0.338239  0.413661  0.358050  0.040627 -0.989763
# 4865 NaN  0.363720  0.338230  0.413660  0.358042  0.040578 -0.989761
# 4866 NaN  0.363730  0.338218  0.413662  0.358037  0.040533 -0.989763
# 4867 NaN  0.363733  0.338206  0.413668  0.358031  0.040491 -0.989762
# 4868 NaN  0.363735  0.338195  0.413676  0.358023  0.040450 -0.989761
#
#             7         8    9       10
# 0     0.326473 -0.393300  0.0  1182.0
# 1     0.326461 -0.393353  0.0  1183.0
# 2     0.326444 -0.393406  0.0  1184.0
# 3     0.326425 -0.393460  0.0  1185.0
# 4     0.326404 -0.393515  0.0  1186.0
# ...        ...       ...  ...     ...
# 4864  0.234949 -0.631394  0.0  6046.0
# 4865  0.234926 -0.631442  0.0  6047.0
# 4866  0.234906 -0.631489  0.0  6048.0
# 4867  0.234890 -0.631537  0.0  6049.0
# 4868  0.234874 -0.631584  0.0  6050.0
#
# [4869 rows x 11 columns]

# %%
del mydata[10]

# %%
mydata.plot()
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
# Create the X, Y, and Z coordinate arrays. 
x = np.linspace(-5, 5, 101)
y = np.linspace(-5, 5, 101)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))
# Create a surface plot and projected filled contour plot under it.
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
# Select Colormap
cmap = cm.viridis
# Norm for color mapping
norm = plt.Normalize(Z.min(), Z.max())
# Plot surface with color mapping
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors=cmap(norm(Z)), alpha=0.9, linewidth=0)
# Add a color bar which maps values to colors
m = cm.ScalarMappable(cmap=cmap, norm=norm)
m.set_array(Z)
fig.colorbar(m)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 21
#      19 m = cm.ScalarMappable(cmap=cmap, norm=norm)
#      20 m.set_array(Z)
# ---> 21 fig.colorbar(m)
#      22 ax.set_xlabel('X')
#      23 ax.set_ylabel('Y')
#
# File c:\Users\david\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\figure.py:1213, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1211 if cax is None:
#    1212     if ax is None:
# -> 1213         raise ValueError(
#    1214             'Unable to determine Axes to steal space for Colorbar. '
#    1215             'Either provide the *cax* argument to use as the Axes for '
#    1216             'the Colorbar, provide the *ax* argument to steal space '
#    1217             'from it, or add *mappable* to an Axes.')
#    1218     fig = (  # Figure of first Axes; logic copied from make_axes.
#    1219         [*ax.flat] if isinstance(ax, np.ndarray)
#    1220         else [*ax] if np.iterable(ax)
#    1221         else [ax])[0].figure
#    1222     current_ax = fig.gca()
#
# ValueError: Unable to determine Axes to steal space for Colorbar. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
